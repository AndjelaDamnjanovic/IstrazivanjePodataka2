# %%
import pandas as pd
import csv

# %%
data = pd.read_csv('datasetNew.csv')
data
# Out:
#         repeat                                           taxonomy  \
# 0         EEEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# 1         EEEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# 2          EEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# 3          EEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# 4          EEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# ...        ...                                                ...
# 1884817    VVT  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
# 1884818    YHN  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
# 1884819    YHN  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
# 1884820    VAE  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
# 1884821    VAE  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
#
#          disorder_content  intersect_ind  contains_ind  \
# 0                0.098299              0             0
# 1                0.098299              0             0
# 2                0.098299              0             0
# 3                0.098299              0             0
# 4                0.098299              0             0
# ...                   ...            ...           ...
# 1884817          0.022581              0             0
# 1884818          0.022581              0             0
# 1884819          0.022581              0             0
# 1884820          0.027248              0             0
# 1884821          0.027248              0             0
#
#                                                   keywords
# 0        density map/peptide/map/molecule/domain/densit...
# 1        density map/peptide/map/molecule/domain/densit...
# 2        density map/peptide/map/molecule/domain/densit...
# 3        density map/peptide/map/molecule/domain/densit...
# 4        density map/peptide/map/molecule/domain/densit...
# ...                                                    ...
# 1884817  lack/disordered/ordered/residue/crystal/region...
# 1884818  lack/disordered/ordered/residue/crystal/region...
# 1884819  lack/disordered/ordered/residue/crystal/region...
# 1884820  lack/disordered/ordered/region/density/electro...
# 1884821  lack/disordered/ordered/region/density/electro...
#
# [1884822 rows x 6 columns]

# %%
replaceOne=data.replace(1,'IND_1')
data=replaceOne.replace(0, 'IND_0')
data
# Out:
#         repeat                                           taxonomy  \
# 0         EEEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# 1         EEEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# 2          EEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# 3          EEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# 4          EEE  Viruses Varidnaviria Bamfordvirae Preplasmivir...
# ...        ...                                                ...
# 1884817    VVT  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
# 1884818    YHN  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
# 1884819    YHN  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
# 1884820    VAE  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
# 1884821    VAE  Eukaryota Discoba Euglenozoa Kinetoplastea Met...
#
#         disorder_content intersect_ind contains_ind  \
# 0               0.098299         IND_0        IND_0
# 1               0.098299         IND_0        IND_0
# 2               0.098299         IND_0        IND_0
# 3               0.098299         IND_0        IND_0
# 4               0.098299         IND_0        IND_0
# ...                  ...           ...          ...
# 1884817         0.022581         IND_0        IND_0
# 1884818         0.022581         IND_0        IND_0
# 1884819         0.022581         IND_0        IND_0
# 1884820         0.027248         IND_0        IND_0
# 1884821         0.027248         IND_0        IND_0
#
#                                                   keywords
# 0        density map/peptide/map/molecule/domain/densit...
# 1        density map/peptide/map/molecule/domain/densit...
# 2        density map/peptide/map/molecule/domain/densit...
# 3        density map/peptide/map/molecule/domain/densit...
# 4        density map/peptide/map/molecule/domain/densit...
# ...                                                    ...
# 1884817  lack/disordered/ordered/residue/crystal/region...
# 1884818  lack/disordered/ordered/residue/crystal/region...
# 1884819  lack/disordered/ordered/residue/crystal/region...
# 1884820  lack/disordered/ordered/region/density/electro...
# 1884821  lack/disordered/ordered/region/density/electro...
#
# [1884822 rows x 6 columns]

# %%
data_intersect=data[['repeat', 'intersect_ind']]
transactions=[]
items=[]
for index, row in data_intersect.iterrows():
    items = [str(x) for x in row.values]
    transactions.append(items)

# %%
transactions
# Out:
# [['EEEE', 'IND_0'],
#  ['EEEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['KKKK', 'IND_0'],
#  ['KKKK', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['PSP', 'IND_0'],
#  ['SPSP', 'IND_0'],
#  ['SPSP', 'IND_0'],
#  ['GLV', 'IND_0'],
#  ['GLV', 'IND_0'],
#  ['GLV', 'IND_0'],
#  ['GLV', 'IND_0'],
#  ['GLV', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['PRT', 'IND_0'],
#  ['PRT', 'IND_0'],
#  ['PRT', 'IND_0'],
#  ['PRT', 'IND_0'],
#  ['PRT', 'IND_0'],
#  ['VEKG', 'IND_0'],
#  ['VEKG', 'IND_0'],
#  ['VEKG', 'IND_0'],
#  ['VEKG', 'IND_0'],
#  ['AKK', 'IND_0'],
#  ['AKK', 'IND_0'],
#  ['AKK', 'IND_1'],
#  ['AKK', 'IND_0'],
#  ['DKE', 'IND_1'],
#  ['DKE', 'IND_1'],
#  ['DKE', 'IND_1'],
#  ['DKE', 'IND_1'],
#  ['DSF', 'IND_0'],
#  ['DSF', 'IND_0'],
#  ['DSF', 'IND_0'],
#  ['DSF', 'IND_0'],
#  ['GDE', 'IND_1'],
#  ['GDE', 'IND_1'],
#  ['GDE', 'IND_0'],
#  ['GDE', 'IND_1'],
#  ['KGL', 'IND_0'],
#  ['KGL', 'IND_0'],
#  ['KGL', 'IND_0'],
#  ['KGL', 'IND_0'],
#  ['KKG', 'IND_1'],
#  ['KKG', 'IND_1'],
#  ['KKG', 'IND_0'],
#  ['KKG', 'IND_1'],
#  ['KKN', 'IND_1'],
#  ['KKN', 'IND_1'],
#  ['KKN', 'IND_1'],
#  ['KKN', 'IND_1'],
#  ['LLS', 'IND_0'],
#  ['LLS', 'IND_0'],
#  ['LLS', 'IND_0'],
#  ['LLS', 'IND_0'],
#  ['LPA', 'IND_0'],
#  ['LPA', 'IND_0'],
#  ['LPA', 'IND_0'],
#  ['LPA', 'IND_0'],
#  ['LQE', 'IND_0'],
#  ['LQE', 'IND_0'],
#  ['LQE', 'IND_0'],
#  ['LQE', 'IND_0'],
#  ['LSH', 'IND_0'],
#  ['LSH', 'IND_0'],
#  ['LSH', 'IND_0'],
#  ['LSH', 'IND_0'],
#  ['NAG', 'IND_0'],
#  ['NAG', 'IND_0'],
#  ['NAG', 'IND_0'],
#  ['NAG', 'IND_0'],
#  ['PAL', 'IND_1'],
#  ['PAL', 'IND_0'],
#  ['PAL', 'IND_1'],
#  ['PAL', 'IND_0'],
#  ['RSK', 'IND_0'],
#  ['RSK', 'IND_0'],
#  ['RSK', 'IND_0'],
#  ['RSK', 'IND_0'],
#  ['VAE', 'IND_1'],
#  ['VAE', 'IND_1'],
#  ['VAE', 'IND_0'],
#  ['VAE', 'IND_1'],
#  ['APA', 'IND_0'],
#  ['APA', 'IND_0'],
#  ['APA', 'IND_0'],
#  ['APA', 'IND_1'],
#  ['APA', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EEE', 'IND_0'],
#  ['EPV', 'IND_0'],
#  ['EPV', 'IND_0'],
#  ['EPV', 'IND_0'],
#  ['EPV', 'IND_1'],
#  ['EPV', 'IND_0'],
#  ['GPQ', 'IND_0'],
#  ['GPQ', 'IND_0'],
#  ['GPQ', 'IND_0'],
#  ['GPQ', 'IND_0'],
#  ['GPQ', 'IND_0'],
#  ['LTY', 'IND_0'],
#  ['LTY', 'IND_0'],
#  ['LTY', 'IND_0'],
#  ['LTY', 'IND_0'],
#  ['LTY', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_1'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_1'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['PAP', 'IND_0'],
#  ['QAP', 'IND_0'],
#  ['QAP', 'IND_0'],
#  ['QAP', 'IND_0'],
#  ['QAP', 'IND_1'],
#  ['QAP', 'IND_0'],
#  ['QPLA', 'IND_0'],
#  ['QPLA', 'IND_0'],
#  ['QPLA', 'IND_0'],
#  ['QPLA', 'IND_1'],
#  ['QPLA', 'IND_0'],
#  ['QPL', 'IND_0'],
#  ['QPL', 'IND_0'],
#  ['QPL', 'IND_0'],
#  ['QPL', 'IND_1'],
#  ['QPL', 'IND_0'],
#  ['QPL', 'IND_0'],
#  ['QPL', 'IND_0'],
#  ['QPL', 'IND_0'],
#  ['QPL', 'IND_0'],
#  ['QPL', 'IND_0'],
#  ['SSL', 'IND_0'],
#  ['SSL', 'IND_0'],
#  ['SSL', 'IND_0'],
#  ['SSL', 'IND_0'],
#  ['SSL', 'IND_0'],
#  ['STA', 'IND_0'],
#  ['STA', 'IND_0'],
#  ['STA', 'IND_0'],
#  ['STA', 'IND_1'],
#  ['STA', 'IND_0'],
#  ['STV', 'IND_0'],
#  ['STV', 'IND_0'],
#  ['STV', 'IND_0'],
#  ['STV', 'IND_1'],
#  ['STV', 'IND_0'],
#  ['TLS', 'IND_0'],
#  ['TLS', 'IND_0'],
#  ['TLS', 'IND_0'],
#  ['TLS', 'IND_0'],
#  ['TLS', 'IND_0'],
#  ['VGPS', 'IND_0'],
#  ['VGPS', 'IND_0'],
#  ['VGPS', 'IND_0'],
#  ['VGPS', 'IND_1'],
#  ['VGPS', 'IND_0'],
#  ['VGP', 'IND_0'],
#  ['VGP', 'IND_0'],
#  ['VGP', 'IND_0'],
#  ['VGP', 'IND_1'],
#  ['VGP', 'IND_0'],
#  ['VGP', 'IND_0'],
#  ['VGP', 'IND_0'],
#  ['VGP', 'IND_0'],
#  ['VGP', 'IND_0'],
#  ['VGP', 'IND_0'],
#  ['VKE', 'IND_0'],
#  ['VKE', 'IND_0'],
#  ['VKE', 'IND_0'],
#  ['VKE', 'IND_0'],
#  ['VKE', 'IND_0'],
#  ['YST', 'IND_0'],
#  ['YST', 'IND_0'],
#  ['YST', 'IND_0'],
#  ['YST', 'IND_1'],
#  ['YST', 'IND_0'],
#  ['MAG', 'IND_0'],
#  ['MAG', 'IND_0'],
#  ['MAG', 'IND_1'],
#  ['MAG', 'IND_0'],
#  ['MAG', 'IND_0'],
#  ['MAG', 'IND_0'],
#  ['MAG', 'IND_0'],
#  ['MAG', 'IND_0'],
#  ['MAG', 'IND_1'],
#  ['AFG', 'IND_0'],
#  ['AFG', 'IND_0'],
#  ['AFG', 'IND_0'],
#  ['AFG', 'IND_0'],
#  ['AFG', 'IND_0'],
#  ['AGK', 'IND_0'],
#  ['AGK', 'IND_0'],
#  ['AGK', 'IND_0'],
#  ['AGK', 'IND_0'],
#  ['AGK', 'IND_0'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_1'],
#  ['AIL', 'IND_0'],
#  ['AIL', 'IND_0'],
#  ['AIL', 'IND_0'],
#  ['AIL', 'IND_0'],
#  ['AIL', 'IND_0'],
#  ['AVQ', 'IND_0'],
#  ['AVQ', 'IND_0'],
#  ['AVQ', 'IND_0'],
#  ['AVQ', 'IND_0'],
#  ['AVQ', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['AVT', 'IND_0'],
#  ['CFF', 'IND_0'],
#  ['CFF', 'IND_0'],
#  ['CFF', 'IND_0'],
#  ['CFF', 'IND_0'],
#  ['CFF', 'IND_0'],
#  ['DEP', 'IND_1'],
#  ['DEP', 'IND_1'],
#  ['DEP', 'IND_1'],
#  ['DEP', 'IND_1'],
#  ['DEP', 'IND_1'],
#  ['DIY', 'IND_0'],
#  ['DIY', 'IND_0'],
#  ['DIY', 'IND_0'],
#  ['DIY', 'IND_0'],
#  ['DIY', 'IND_0'],
#  ['DKI', 'IND_0'],
#  ['DKI', 'IND_0'],
#  ['DKI', 'IND_0'],
#  ['DKI', 'IND_0'],
#  ['DKI', 'IND_0'],
#  ['DSI', 'IND_0'],
#  ['DSI', 'IND_0'],
#  ['DSI', 'IND_0'],
#  ['DSI', 'IND_0'],
#  ['DSI', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['DSL', 'IND_0'],
#  ['EAM', 'IND_0'],
#  ['EAM', 'IND_0'],
#  ['EAM', 'IND_0'],
#  ['EAM', 'IND_0'],
#  ['EAM', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EED', 'IND_0'],
#  ['EGE', 'IND_0'],
#  ['EGE', 'IND_0'],
#  ['EGE', 'IND_0'],
#  ['EGE', 'IND_0'],
#  ['EGE', 'IND_0'],
#  ['EGG', 'IND_0'],
#  ['EGG', 'IND_0'],
#  ['EGG', 'IND_0'],
#  ['EGG', 'IND_0'],
#  ['EGG', 'IND_0'],
#  ['EGK', 'IND_0'],
#  ['EGK', 'IND_0'],
#  ['EGK', 'IND_0'],
#  ['EGK', 'IND_0'],
#  ['EGK', 'IND_0'],
#  ['EGR', 'IND_0'],
#  ['EGR', 'IND_0'],
#  ['EGR', 'IND_0'],
#  ['EGR', 'IND_0'],
#  ['EGR', 'IND_0'],
#  ['EKA', 'IND_0'],
#  ['EKA', 'IND_0'],
#  ['EKA', 'IND_0'],
#  ['EKA', 'IND_0'],
#  ['EKA', 'IND_0'],
#  ['EMI', 'IND_0'],
#  ['EMI', 'IND_0'],
#  ['EMI', 'IND_0'],
#  ['EMI', 'IND_0'],
#  ['EMI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['ENI', 'IND_0'],
#  ['EPS', 'IND_0'],
#  ['EPS', 'IND_0'],
#  ['EPS', 'IND_0'],
#  ['EPS', 'IND_0'],
#  ['EPS', 'IND_0'],
#  ['ERR', 'IND_0'],
#  ['ERR', 'IND_0'],
#  ['ERR', 'IND_0'],
#  ['ERR', 'IND_0'],
#  ['ERR', 'IND_0'],
#  ['ERS', 'IND_0'],
#  ['ERS', 'IND_0'],
#  ['ERS', 'IND_0'],
#  ['ERS', 'IND_0'],
#  ['ERS', 'IND_0'],
#  ['ETL', 'IND_0'],
#  ['ETL', 'IND_0'],
#  ['ETL', 'IND_1'],
#  ['ETL', 'IND_1'],
#  ['ETL', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FFS', 'IND_0'],
#  ['FGE', 'IND_0'],
#  ['FGE', 'IND_0'],
#  ['FGE', 'IND_0'],
#  ['FGE', 'IND_0'],
#  ['FGE', 'IND_0'],
#  ['FGV', 'IND_0'],
#  ['FGV', 'IND_0'],
#  ['FGV', 'IND_0'],
#  ['FGV', 'IND_0'],
#  ['FGV', 'IND_0'],
#  ['FLQ', 'IND_0'],
#  ['FLQ', 'IND_0'],
#  ['FLQ', 'IND_0'],
#  ['FLQ', 'IND_0'],
#  ['FLQ', 'IND_0'],
#  ['FLYL', 'IND_0'],
#  ['FLYL', 'IND_0'],
#  ['FLYL', 'IND_0'],
#  ['FLYL', 'IND_0'],
#  ['FLYL', 'IND_0'],
#  ['FSG', 'IND_0'],
#  ['FSG', 'IND_0'],
#  ['FSG', 'IND_0'],
#  ['FSG', 'IND_0'],
#  ['FSG', 'IND_0'],
#  ['FSI', 'IND_1'],
#  ['FSI', 'IND_1'],
#  ['FSI', 'IND_1'],
#  ['FSI', 'IND_1'],
#  ['FSI', 'IND_1'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSL', 'IND_0'],
#  ['FSW', 'IND_0'],
#  ['FSW', 'IND_0'],
#  ['FSW', 'IND_0'],
#  ['FSW', 'IND_0'],
#  ['FSW', 'IND_0'],
#  ['FVL', 'IND_0'],
#  ['FVL', 'IND_0'],
#  ['FVL', 'IND_0'],
#  ['FVL', 'IND_0'],
#  ['FVL', 'IND_0'],
#  ['FYG', 'IND_0'],
#  ['FYG', 'IND_0'],
#  ['FYG', 'IND_0'],
#  ['FYG', 'IND_0'],
#  ['FYG', 'IND_0'],
#  ['GAI', 'IND_0'],
#  ['GAI', 'IND_0'],
#  ['GAI', 'IND_0'],
#  ['GAI', 'IND_0'],
#  ['GAI', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEG', 'IND_0'],
#  ['GEL', 'IND_0'],
#  ['GEL', 'IND_0'],
#  ['GEL', 'IND_0'],
#  ['GEL', 'IND_0'],
#  ['GEL', 'IND_0'],
#  ['GFF', 'IND_0'],
#  ['GFF', 'IND_0'],
#  ['GFF', 'IND_0'],
#  ['GFF', 'IND_0'],
#  ['GFF', 'IND_0'],
#  ['GGI', 'IND_0'],
#  ['GGI', 'IND_0'],
#  ['GGI', 'IND_0'],
#  ['GGI', 'IND_0'],
#  ['GGI', 'IND_0'],
#  ['GIIL', 'IND_0'],
#  ['GIIL', 'IND_0'],
#  ['GIIL', 'IND_0'],
#  ['GIIL', 'IND_0'],
#  ['GIIL', 'IND_0'],
#  ['GKI', 'IND_0'],
#  ['GKI', 'IND_0'],
#  ['GKI', 'IND_0'],
#  ['GKI', 'IND_0'],
#  ['GKI', 'IND_0'],
#  ['GLG', 'IND_0'],
#  ['GLG', 'IND_0'],
#  ['GLG', 'IND_0'],
#  ['GLG', 'IND_0'],
#  ['GLG', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQL', 'IND_0'],
#  ['GQR', 'IND_0'],
#  ['GQR', 'IND_0'],
#  ['GQR', 'IND_0'],
#  ['GQR', 'IND_0'],
#  ['GQR', 'IND_0'],
#  ['GRI', 'IND_0'],
#  ['GRI', 'IND_0'],
#  ['GRI', 'IND_0'],
#  ['GRI', 'IND_0'],
#  ['GRI', 'IND_0'],
#  ['GTF', 'IND_0'],
#  ['GTF', 'IND_0'],
#  ['GTF', 'IND_0'],
#  ['GTF', 'IND_0'],
#  ['GTF', 'IND_0'],
#  ['GVS', 'IND_0'],
#  ['GVS', 'IND_0'],
#  ['GVS', 'IND_0'],
#  ['GVS', 'IND_0'],
#  ['GVS', 'IND_0'],
#  ['HSV', 'IND_1'],
#  ['HSV', 'IND_1'],
#  ['HSV', 'IND_1'],
#  ['HSV', 'IND_1'],
#  ['HSV', 'IND_1'],
#  ['IAI', 'IND_0'],
#  ['IAI', 'IND_0'],
#  ['IAI', 'IND_0'],
#  ['IAI', 'IND_0'],
#  ['IAI', 'IND_0'],
#  ['IAV', 'IND_0'],
#  ['IAV', 'IND_0'],
#  ['IAV', 'IND_0'],
#  ['IAV', 'IND_0'],
#  ['IAV', 'IND_0'],
#  ['IEE', 'IND_1'],
#  ['IEE', 'IND_1'],
#  ['IEE', 'IND_1'],
#  ['IEE', 'IND_1'],
#  ['IEE', 'IND_1'],
#  ['IEN', 'IND_0'],
#  ['IEN', 'IND_0'],
#  ['IEN', 'IND_0'],
#  ['IEN', 'IND_0'],
#  ['IEN', 'IND_0'],
#  ['IEN', 'IND_0'],
#  ['IEN', 'IND_0'],
#  ['IEN', 'IND_0'],
#  ['IEN', 'IND_0'],
#  ['IEN', 'IND_0'],
#  ['IFG', 'IND_0'],
#  ['IFG', 'IND_0'],
#  ['IFG', 'IND_0'],
#  ['IFG', 'IND_0'],
#  ['IFG', 'IND_0'],
#  ['IFL', 'IND_0'],
#  ['IFL', 'IND_0'],
#  ['IFL', 'IND_0'],
#  ['IFL', 'IND_0'],
#  ['IFL', 'IND_0'],
#  ['IFT', 'IND_0'],
#  ['IFT', 'IND_0'],
#  ['IFT', 'IND_0'],
#  ['IFT', 'IND_0'],
#  ['IFT', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['IFV', 'IND_0'],
#  ['ILH', 'IND_0'],
#  ['ILH', 'IND_0'],
#  ['ILH', 'IND_0'],
#  ['ILH', 'IND_0'],
#  ['ILH', 'IND_0'],
#  ['ILN', 'IND_0'],
#  ['ILN', 'IND_0'],
#  ['ILN', 'IND_1'],
#  ['ILN', 'IND_1'],
#  ['ILN', 'IND_0'],
#  ['ILRK', 'IND_0'],
#  ['ILRK', 'IND_0'],
#  ['ILRK', 'IND_0'],
#  ['ILRK', 'IND_0'],
#  ['ILRK', 'IND_0'],
#  ['ILT', 'IND_0'],
#  ['ILT', 'IND_0'],
#  ['ILT', 'IND_1'],
#  ['ILT', 'IND_1'],
#  ['ILT', 'IND_0'],
#  ['ILT', 'IND_0'],
#  ['ILT', 'IND_0'],
#  ['ILT', 'IND_0'],
#  ['ILT', 'IND_0'],
#  ['ILT', 'IND_0'],
#  ['ISE', 'IND_0'],
#  ['ISE', 'IND_0'],
#  ['ISE', 'IND_0'],
#  ['ISE', 'IND_0'],
#  ['ISE', 'IND_0'],
#  ['ISFC', 'IND_0'],
#  ['ISFC', 'IND_0'],
#  ['ISFC', 'IND_0'],
#  ['ISFC', 'IND_0'],
#  ['ISFC', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISF', 'IND_0'],
#  ['ISI', 'IND_0'],
#  ['ISI', 'IND_0'],
#  ['ISI', 'IND_0'],
#  ['ISI', 'IND_0'],
#  ['ISI', 'IND_0'],
#  ['ISP', 'IND_0'],
#  ['ISP', 'IND_0'],
#  ['ISP', 'IND_0'],
#  ['ISP', 'IND_0'],
#  ['ISP', 'IND_0'],
#  ['ITL', 'IND_0'],
#  ['ITL', 'IND_0'],
#  ['ITL', 'IND_0'],
#  ['ITL', 'IND_0'],
#  ['ITL', 'IND_0'],
#  ['ITS', 'IND_0'],
#  ['ITS', 'IND_0'],
#  ['ITS', 'IND_0'],
#  ['ITS', 'IND_0'],
#  ['ITS', 'IND_0'],
#  ['ITV', 'IND_0'],
#  ['ITV', 'IND_0'],
#  ['ITV', 'IND_0'],
#  ['ITV', 'IND_0'],
#  ['ITV', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['IVL', 'IND_0'],
#  ['KAK', 'IND_0'],
#  ['KAK', 'IND_0'],
#  ['KAK', 'IND_0'],
#  ['KAK', 'IND_0'],
#  ['KAK', 'IND_0'],
#  ['KDI', 'IND_0'],
#  ['KDI', 'IND_0'],
#  ['KDI', 'IND_0'],
#  ['KDI', 'IND_0'],
#  ['KDI', 'IND_0'],
#  ['KEE', 'IND_0'],
#  ['KEE', 'IND_0'],
#  ['KEE', 'IND_0'],
#  ['KEE', 'IND_0'],
#  ['KEE', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIL', 'IND_0'],
#  ['KIS', 'IND_0'],
#  ['KIS', 'IND_0'],
#  ['KIS', 'IND_0'],
#  ['KIS', 'IND_0'],
#  ['KIS', 'IND_0'],
#  ['KLF', 'IND_0'],
#  ['KLF', 'IND_0'],
#  ['KLF', 'IND_0'],
#  ['KLF', 'IND_0'],
#  ['KLF', 'IND_0'],
#  ['KLM', 'IND_0'],
#  ['KLM', 'IND_0'],
#  ['KLM', 'IND_0'],
#  ['KLM', 'IND_0'],
#  ['KLM', 'IND_0'],
#  ['KQL', 'IND_0'],
#  ['KQL', 'IND_0'],
#  ['KQL', 'IND_0'],
#  ['KQL', 'IND_0'],
#  ['KQL', 'IND_0'],
#  ['KST', 'IND_0'],
#  ['KST', 'IND_0'],
#  ['KST', 'IND_0'],
#  ['KST', 'IND_0'],
#  ['KST', 'IND_0'],
#  ['KTL', 'IND_0'],
#  ['KTL', 'IND_0'],
#  ['KTL', 'IND_0'],
#  ['KTL', 'IND_0'],
#  ['KTL', 'IND_0'],
#  ['KTS', 'IND_0'],
#  ['KTS', 'IND_0'],
#  ['KTS', 'IND_0'],
#  ['KTS', 'IND_0'],
#  ['KTS', 'IND_0'],
#  ['LAL', 'IND_0'],
#  ['LAL', 'IND_0'],
#  ['LAL', 'IND_0'],
#  ['LAL', 'IND_0'],
#  ['LAL', 'IND_0'],
#  ['LAM', 'IND_0'],
#  ['LAM', 'IND_0'],
#  ['LAM', 'IND_0'],
#  ['LAM', 'IND_0'],
#  ['LAM', 'IND_0'],
#  ['LAR', 'IND_0'],
#  ['LAR', 'IND_0'],
#  ['LAR', 'IND_0'],
#  ['LAR', 'IND_0'],
#  ['LAR', 'IND_0'],
#  ['LDP', 'IND_0'],
#  ['LDP', 'IND_0'],
#  ['LDP', 'IND_0'],
#  ['LDP', 'IND_0'],
#  ['LDP', 'IND_0'],
#  ['LER', 'IND_0'],
#  ['LER', 'IND_0'],
#  ['LER', 'IND_0'],
#  ['LER', 'IND_0'],
#  ['LER', 'IND_0'],
#  ['LFFS', 'IND_0'],
#  ['LFFS', 'IND_0'],
#  ['LFFS', 'IND_0'],
#  ['LFFS', 'IND_0'],
#  ['LFFS', 'IND_0'],
#  ['LGE', 'IND_0'],
#  ['LGE', 'IND_0'],
#  ['LGE', 'IND_0'],
#  ['LGE', 'IND_0'],
#  ['LGE', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LGR', 'IND_0'],
#  ['LHH', 'IND_0'],
#  ['LHH', 'IND_0'],
#  ['LHH', 'IND_0'],
#  ['LHH', 'IND_0'],
#  ['LHH', 'IND_0'],
#  ['LIV', 'IND_0'],
#  ['LIV', 'IND_0'],
#  ['LIV', 'IND_0'],
#  ['LIV', 'IND_0'],
#  ['LIV', 'IND_0'],
#  ['LIW', 'IND_0'],
#  ['LIW', 'IND_0'],
#  ['LIW', 'IND_0'],
#  ['LIW', 'IND_0'],
#  ['LIW', 'IND_0'],
#  ['LKE', 'IND_1'],
#  ['LKE', 'IND_1'],
#  ['LKE', 'IND_1'],
#  ['LKE', 'IND_1'],
#  ['LKE', 'IND_1'],
#  ['LKL', 'IND_0'],
#  ['LKL', 'IND_0'],
#  ['LKL', 'IND_0'],
#  ['LKL', 'IND_0'],
#  ['LKL', 'IND_0'],
#  ['LKQ', 'IND_0'],
#  ['LKQ', 'IND_0'],
#  ['LKQ', 'IND_0'],
#  ['LKQ', 'IND_0'],
#  ['LKQ', 'IND_0'],
#  ['LLA', 'IND_0'],
#  ['LLA', 'IND_0'],
#  ['LLA', 'IND_0'],
#  ['LLA', 'IND_0'],
#  ['LLA', 'IND_0'],
#  ['LLD', 'IND_0'],
#  ['LLD', 'IND_0'],
#  ['LLD', 'IND_0'],
#  ['LLD', 'IND_0'],
#  ['LLD', 'IND_0'],
#  ['LLGR', 'IND_0'],
#  ['LLGR', 'IND_0'],
#  ['LLGR', 'IND_0'],
#  ['LLGR', 'IND_0'],
#  ['LLGR', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLG', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLL', 'IND_0'],
#  ['LLM', 'IND_0'],
#  ['LLM', 'IND_0'],
#  ['LLM', 'IND_0'],
#  ['LLM', 'IND_0'],
#  ['LLM', 'IND_0'],
#  ['LLN', 'IND_0'],
#  ['LLN', 'IND_0'],
#  ['LLN', 'IND_0'],
#  ['LLN', 'IND_0'],
#  ['LLN', 'IND_0'],
#  ['LLS', 'IND_0'],
#  ['LLS', 'IND_0'],
#  ['LLS', 'IND_0'],
#  ['LLS', 'IND_0'],
#  ['LLS', 'IND_0'],
#  ['LMG', 'IND_0'],
#  ['LMG', 'IND_0'],
#  ['LMG', 'IND_0'],
#  ['LMG', 'IND_0'],
#  ['LMG', 'IND_0'],
#  ['LNL', 'IND_1'],
#  ['LNL', 'IND_1'],
#  ['LNL', 'IND_1'],
#  ['LNL', 'IND_1'],
#  ['LNL', 'IND_1'],
#  ['LNT', 'IND_0'],
#  ['LNT', 'IND_0'],
#  ['LNT', 'IND_0'],
#  ['LNT', 'IND_0'],
#  ['LNT', 'IND_0'],
#  ['LPL', 'IND_0'],
#  ['LPL', 'IND_0'],
#  ['LPL', 'IND_0'],
#  ['LPL', 'IND_0'],
#  ['LPL', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_0'],
#  ['LQA', 'IND_1'],
#  ['LQA', 'IND_1'],
#  ['LQA', 'IND_1'],
#  ['LQA', 'IND_1'],
#  ['LQA', 'IND_1'],
#  ['LQP', 'IND_0'],
#  ['LQP', 'IND_0'],
#  ['LQP', 'IND_0'],
#  ['LQP', 'IND_0'],
#  ['LQP', 'IND_0'],
#  ['LRA', 'IND_0'],
#  ['LRA', 'IND_0'],
#  ['LRA', 'IND_0'],
#  ['LRA', 'IND_0'],
#  ['LRA', 'IND_0'],
#  ['LSK', 'IND_0'],
#  ['LSK', 'IND_0'],
#  ['LSK', 'IND_0'],
#  ['LSK', 'IND_0'],
#  ['LSK', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTE', 'IND_0'],
#  ['LTT', 'IND_0'],
#  ['LTT', 'IND_0'],
#  ...]

# %%
#provera da li i dalje ima svih transakcija
print(len(transactions))
# Out:
# 1884822

# %%
file=open("transactions.csv", "w")
row_lists=[["repeat", "intersect_ind"]]
writer = csv.writer(file, delimiter=',')
for transaction in transactions:
    row_lists.append(transaction)
writer.writerows(row_lists)
file.close()

# %%
data_intersect=data[['repeat', 'intersect_ind', 'keywords']]
transactions=[]
items=[]
for index, row in data_intersect.iterrows():
    items = [str(x) for x in row.values]
    transactions.append(items)

# %%
transactions
# Out:
# [['EEEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['EEE',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['KKKK',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['KKKK',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['PSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['SPSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['SPSP',
#   'IND_0',
#   'density map/peptide/map/molecule/domain/density/electron density map/visible/terminus/electron/first/electron density/chain'],
#  ['GLV',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['GLV',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['GLV',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['GLV',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['GLV',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLG',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLG',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLG',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLG',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLG',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLL',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLL',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLL',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLL',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['LLL',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['PRT',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['PRT',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['PRT',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['PRT',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['PRT',
#   'IND_0',
#   'change/activity/crystal structure/form/high/free/disordered/secondary structure/position/helix/value/solution/cell/using/analysis/highly/coil/structural/spectrum/electron/secondary/peptide/ordered/sequence/crystal/data/conformation/observed/structure/show'],
#  ['VEKG',
#   'IND_0',
#   'protein/analysis/bind/random/large/part/binding/form/value/coil/data/conformation/using'],
#  ['VEKG',
#   'IND_0',
#   'protein/analysis/bind/random/large/part/binding/form/value/coil/data/conformation/using'],
#  ['VEKG',
#   'IND_0',
#   'protein/analysis/bind/random/large/part/binding/form/value/coil/data/conformation/using'],
#  ['VEKG',
#   'IND_0',
#   'protein/analysis/bind/random/large/part/binding/form/value/coil/data/conformation/using'],
#  ['AKK',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['AKK',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['AKK',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['AKK',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['DKE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['DKE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['DKE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['DKE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['DSF',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['DSF',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['DSF',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['DSF',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['GDE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['GDE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['GDE',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['GDE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KGL',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KGL',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KGL',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KGL',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KKG',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KKG',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KKG',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KKG',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KKN',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KKN',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KKN',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['KKN',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LLS',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LLS',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LLS',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LLS',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LPA',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LPA',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LPA',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LPA',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LQE',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LQE',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LQE',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LQE',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LSH',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LSH',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LSH',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['LSH',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['NAG',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['NAG',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['NAG',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['NAG',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['PAL',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['PAL',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['PAL',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['PAL',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['RSK',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['RSK',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['RSK',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['RSK',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['VAE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['VAE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['VAE',
#   'IND_0',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['VAE',
#   'IND_1',
#   'density map/lack/residue/flexible/map/amino/molecule/acid/amino acid/density/electron density map/visible/terminus/electron/first/electron density'],
#  ['APA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['APA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['APA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['APA',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['APA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EEE',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EEE',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EEE',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EEE',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EEE',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EPV',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EPV',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EPV',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EPV',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['EPV',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['GPQ',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['GPQ',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['GPQ',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['GPQ',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['GPQ',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['LTY',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['LTY',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['LTY',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['LTY',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['LTY',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['PAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QAP',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QAP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPLA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPLA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPLA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPLA',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPLA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['QPL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['SSL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['SSL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['SSL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['SSL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['SSL',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STA',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STA',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STV',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STV',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STV',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STV',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['STV',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['TLS',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['TLS',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['TLS',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['TLS',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['TLS',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGPS',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGPS',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGPS',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGPS',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGPS',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_1',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VGP',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VKE',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VKE',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VKE',
#   'IND_0',
#   'lack/result/indicate/rna/form/protein/table/circular dichroism/free/large/position/helix/value/consistent/segment/random/bind/experiment/domain/indicating/chain/indicated/peptide/complex/ordered/addition/binding/data/structure/show'],
#  ['VKE',
#   'IND_0',
# ...
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LMG',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNL',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNL',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNL',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNL',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNL',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNT',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNT',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNT',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNT',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LNT',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LPL',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LPL',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LPL',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LPL',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LPL',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQA',
#   'IND_1',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQP',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQP',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQP',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQP',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LQP',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LRA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LRA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LRA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LRA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LRA',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LSK',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LSK',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LSK',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LSK',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LSK',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTE',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTT',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ['LTT',
#   'IND_0',
#   'change/activity/resonance/form/suggesting/similar/high/protein/chemical/random coil/disordered/large/value/one/peak/random/residue/highly/coil/structural/spectrum/ordered/region/unstructured/data/conformation/structure/show'],
#  ...]

# %%
file=open("transactionsWithKeywords.csv", "w")
row_lists=[["repeat", "intersect_ind", "keywords"]]
writer = csv.writer(file, delimiter=',')
for transaction in transactions:
    row_lists.append(transaction)
writer.writerows(row_lists)
file.close()

# %%
data_intersect=data[['repeat', 'intersect_ind', 'taxonomy']]
transactions=[]
items=[]
for index, row in data_intersect.iterrows():
    items = [str(x) for x in row.values]
    transactions.append(items)

# %%
transactions
# Out:
# [['EEEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['EEE',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['KKKK',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['KKKK',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['PSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['SPSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['SPSP',
#   'IND_0',
#   'Viruses Varidnaviria Bamfordvirae Preplasmiviricota Tectiliviricetes Rowavirales Adenoviridae Mastadenovirus'],
#  ['GLV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['GLV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['GLV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['GLV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['GLV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['PRT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['PRT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['PRT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['PRT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['PRT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['VEKG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Laurasiatheria Perissodactyla Equidae Equus'],
#  ['VEKG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Laurasiatheria Perissodactyla Equidae Equus'],
#  ['VEKG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Laurasiatheria Perissodactyla Equidae Equus'],
#  ['VEKG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Laurasiatheria Perissodactyla Equidae Equus'],
#  ['AKK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AKK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AKK',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AKK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['DKE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['DKE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['DKE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['DKE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['DSF',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['DSF',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['DSF',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['DSF',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['GDE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['GDE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['GDE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['GDE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KGL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KGL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KGL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KGL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KKG',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KKG',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KKG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KKG',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KKN',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KKN',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KKN',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['KKN',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LPA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LPA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LPA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LPA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LSH',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LSH',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LSH',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LSH',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['NAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['NAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['NAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['NAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['PAL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['PAL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['PAL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['PAL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['RSK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['RSK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['RSK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['RSK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['VAE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['VAE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['VAE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['VAE',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['APA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['APA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['APA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['APA',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['APA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EEE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EEE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EEE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EEE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EEE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EPV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EPV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EPV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EPV',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['EPV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['GPQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['GPQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['GPQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['GPQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['GPQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['LTY',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['LTY',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['LTY',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['LTY',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['LTY',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['PAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QAP',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QAP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPLA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPLA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPLA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPLA',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPLA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['QPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['SSL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['SSL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['SSL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['SSL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['SSL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STA',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STV',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['STV',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['TLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['TLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['TLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['TLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['TLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGPS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGPS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGPS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGPS',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGPS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VGP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VKE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VKE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VKE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VKE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['VKE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['YST',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['YST',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['YST',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['YST',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['YST',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Glires Rodentia Myomorpha Muroidea Muridae Murinae Mus Mus'],
#  ['MAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['MAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['MAG',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['MAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['MAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['MAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['MAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['MAG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['MAG',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AFG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AFG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AFG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AFG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AFG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AGK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AGK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AGK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AGK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AGK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AIL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVQ',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['AVT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['CFF',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['CFF',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['CFF',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['CFF',
#   'IND_0',
# ...
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLM',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLM',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLM',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLM',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLM',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLN',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLN',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLN',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLN',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLN',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LLS',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LMG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LMG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LMG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LMG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LMG',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNL',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LNT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LPL',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQA',
#   'IND_1',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LQP',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LRA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LRA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LRA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LRA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LRA',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LSK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LSK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LSK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LSK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LSK',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTE',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ['LTT',
#   'IND_0',
#   'Eukaryota Metazoa Chordata Craniata Vertebrata Euteleostomi Mammalia Eutheria Euarchontoglires Primates Haplorrhini Catarrhini Hominidae Homo'],
#  ...]

# %%
file=open("transactionsWithTaxonomy.csv", "w")
row_lists=[["repeat", "intersect_ind", "taxonomy"]]
writer = csv.writer(file, delimiter=',')
for transaction in transactions:
    row_lists.append(transaction)
writer.writerows(row_lists)
file.close()
